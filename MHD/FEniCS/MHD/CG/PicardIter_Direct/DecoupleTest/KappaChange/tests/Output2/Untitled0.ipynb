# %%
import pandas as pd
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
pd.read_csv('Fullmutest')
# Out:
#    Unnamed: 0  l      DoF            it          it.1          it.2  it.3  \
# 0           0  0        0  1.000000e-01  0.000000e+00  0.000000e+00     1
# 1           1  5    24132  1.000000e+13  6.000000e-11  4.500000e-11     6
# 2           2  6    95364  1.300000e+01  9.153846e+01  6.338462e+01     6
# 3           3  7   379140  1.000000e+01  7.460000e+01  3.140000e+01     7
# 4           4  8  1511940  1.200000e+01  8.233333e+01  3.775000e+01     8
#
#         it.4       it.5  it.6       it.7       it.8  it.9      it.10  \
# 0   0.000000   0.000000    10   0.000000   0.000000   100   0.000000
# 1  27.333333  15.166667     6   9.833333  12.666667     5   7.400000
# 2  20.166667  15.333333     6   9.666667  11.333333     6   8.666667
# 3  16.285714  14.285714     7  14.571429  15.857143     6   8.666667
# 4  24.250000  14.875000     7  15.428571  15.714286     7  24.000000
#
#        it.11
# 0   0.000000
# 1   9.800000
# 2  11.333333
# 3  12.333333
# 4  13.714286
